# %%
import optuna
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.metrics import AUC, Precision, Recall
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load and preprocess the dataset
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '111/train',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '111/validation',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)
# Out:
# Found 7771 files belonging to 4 classes.
# Found 1943 files belonging to 4 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(labels[i].numpy())
        plt.axis("off")

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %%
# Load EfficientNetB0 without top layers
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze initial layers

# %%
# Define the objective function for Optuna
def objective(trial):
    # Suggest values for dropout rate and learning rate
    dropout_rate = trial.suggest_float("dropout_rate", 0.3, 0.7)
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-3)

    # Build the model
    inputs = tf.keras.Input(shape=(224, 224, 3))
    x = data_augmentation(inputs)
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(4, activation='softmax')(x)  # Assuming 4 classes
    
    model = models.Model(inputs, outputs)

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Callbacks for early stopping and learning rate reduction
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, verbose=1)

    # Train the model with a small number of epochs for quick evaluation
    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=5,  # Reduced epochs to speed up optimization
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Return the best validation loss as the objective value
    val_loss = min(history.history['val_loss'])
    return val_loss

# %%
# Run the Optuna study
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)  # Run 10 trials for optimization
# Out:
# [I 2024-11-29 11:16:42,878] A new study created in memory with name: no-name-a06bf61d-532a-4999-bebd-93a7e978f40c
# Epoch 1/5
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_12084\2865568676.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-3)
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 530s 2s/step - accuracy: 0.5661 - loss: 1.4866 - val_accuracy: 0.9331 - val_loss: 0.2278 - learning_rate: 1.4236e-04
# Epoch 2/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.8515 - loss: 0.4612 - val_accuracy: 0.9547 - val_loss: 0.1208 - learning_rate: 1.4236e-04
# Epoch 3/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8885 - loss: 0.3479 - val_accuracy: 0.9629 - val_loss: 0.0959 - learning_rate: 1.4236e-04
# %%
# Get the best parameters
best_params = study.best_params
print("Best parameters found by Optuna:", best_params)
# Out:
# Best parameters found by Optuna: {'dropout_rate': 0.33792976311541406, 'learning_rate': 0.0007210793776538638}

# %%
# Final model with optimized parameters
best_dropout_rate = best_params['dropout_rate']
best_learning_rate = best_params['learning_rate']

# %%
# Build and compile the final model
final_model = models.Sequential([
    tf.keras.Input(shape=(224, 224, 3)),
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dropout(best_dropout_rate),
    layers.Dense(1024, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(best_dropout_rate),
    layers.Dense(4, activation='softmax')
])

# %%
# Compile with optimized learning rate
final_model.compile(optimizer=Adam(learning_rate=best_learning_rate),
                    loss='categorical_crossentropy',
                    metrics=['accuracy', AUC(name='auc'), Precision(name='precision'), Recall(name='recall')])

# %%
# Callbacks for final training
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1)

# %%
# Train the final model
history = final_model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=15,  # Full training
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 538s 2s/step - accuracy: 0.8771 - auc: 0.9705 - loss: 0.3992 - precision: 0.8871 - recall: 0.8715 - val_accuracy: 0.9583 - val_auc: 0.9969 - val_loss: 0.1164 - val_precision: 0.9592 - val_recall: 0.9563 - learning_rate: 7.2108e-04
# Epoch 2/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 470s 2s/step - accuracy: 0.9596 - auc: 0.9953 - loss: 0.1228 - precision: 0.9605 - recall: 0.9582 - val_accuracy: 0.9748 - val_auc: 0.9978 - val_loss: 0.0777 - val_precision: 0.9748 - val_recall: 0.9743 - learning_rate: 7.2108e-04
# Epoch 3/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 472s 2s/step - accuracy: 0.9635 - auc: 0.9968 - loss: 0.1078 - precision: 0.9640 - recall: 0.9622 - val_accuracy: 0.9810 - val_auc: 0.9989 - val_loss: 0.0573 - val_precision: 0.9810 - val_recall: 0.9810 - learning_rate: 7.2108e-04
# Epoch 4/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.9666 - auc: 0.9960 - loss: 0.1030 - precision: 0.9670 - recall: 0.9662 - val_accuracy: 0.9887 - val_auc: 0.9985 - val_loss: 0.0390 - val_precision: 0.9887 - val_recall: 0.9882 - learning_rate: 7.2108e-04
# Epoch 5/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 482s 2s/step - accuracy: 0.9749 - auc: 0.9975 - loss: 0.0805 - precision: 0.9756 - recall: 0.9747 - val_accuracy: 0.9804 - val_auc: 0.9986 - val_loss: 0.0502 - val_precision: 0.9820 - val_recall: 0.9804 - learning_rate: 7.2108e-04
# Epoch 6/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.9697 - auc: 0.9977 - loss: 0.0844 - precision: 0.9703 - recall: 0.9693 - val_accuracy: 0.9876 - val_auc: 0.9998 - val_loss: 0.0319 - val_precision: 0.9876 - val_recall: 0.9876 - learning_rate: 7.2108e-04
# Epoch 7/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 475s 2s/step - accuracy: 0.9798 - auc: 0.9985 - loss: 0.0619 - precision: 0.9800 - recall: 0.9789 - val_accuracy: 0.9887 - val_auc: 0.9998 - val_loss: 0.0301 - val_precision: 0.9887 - val_recall: 0.9887 - learning_rate: 7.2108e-04
# Epoch 8/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 478s 2s/step - accuracy: 0.9778 - auc: 0.9987 - loss: 0.0664 - precision: 0.9785 - recall: 0.9773 - val_accuracy: 0.9835 - val_auc: 0.9987 - val_loss: 0.0501 - val_precision: 0.9840 - val_recall: 0.9830 - learning_rate: 7.2108e-04
# Epoch 9/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 475s 2s/step - accuracy: 0.9744 - auc: 0.9978 - loss: 0.0757 - precision: 0.9756 - recall: 0.9743 - val_accuracy: 0.9799 - val_auc: 0.9992 - val_loss: 0.0553 - val_precision: 0.9804 - val_recall: 0.9799 - learning_rate: 7.2108e-04
# Epoch 10/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 477s 2s/step - accuracy: 0.9824 - auc: 0.9985 - loss: 0.0555 - precision: 0.9825 - recall: 0.9817 - val_accuracy: 0.9913 - val_auc: 0.9999 - val_loss: 0.0200 - val_precision: 0.9913 - val_recall: 0.9913 - learning_rate: 7.2108e-04
# Epoch 11/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 479s 2s/step - accuracy: 0.9769 - auc: 0.9985 - loss: 0.0661 - precision: 0.9775 - recall: 0.9769 - val_accuracy: 0.9846 - val_auc: 0.9990 - val_loss: 0.0447 - val_precision: 0.9846 - val_recall: 0.9846 - learning_rate: 7.2108e-04
# Epoch 12/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 482s 2s/step - accuracy: 0.9800 - auc: 0.9987 - loss: 0.0568 - precision: 0.9805 - recall: 0.9798 - val_accuracy: 0.9856 - val_auc: 0.9998 - val_loss: 0.0372 - val_precision: 0.9856 - val_recall: 0.9856 - learning_rate: 7.2108e-04
# Epoch 13/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9795 - auc: 0.9980 - loss: 0.0642 - precision: 0.9799 - recall: 0.9792
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00014421587111428382.
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 479s 2s/step - accuracy: 0.9795 - auc: 0.9980 - loss: 0.0642 - precision: 0.9799 - recall: 0.9792 - val_accuracy: 0.9892 - val_auc: 0.9999 - val_loss: 0.0264 - val_precision: 0.9892 - val_recall: 0.9892 - learning_rate: 7.2108e-04
# Epoch 14/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2529s 10s/step - accuracy: 0.9806 - auc: 0.9991 - loss: 0.0475 - precision: 0.9816 - recall: 0.9806 - val_accuracy: 0.9913 - val_auc: 0.9999 - val_loss: 0.0208 - val_precision: 0.9913 - val_recall: 0.9913 - learning_rate: 1.4422e-04
# Epoch 15/15
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 503s 2s/step - accuracy: 0.9842 - auc: 0.9987 - loss: 0.0477 - precision: 0.9847 - recall: 0.9840 - val_accuracy: 0.9913 - val_auc: 0.9999 - val_loss: 0.0191 - val_precision: 0.9913 - val_recall: 0.9913 - learning_rate: 1.4422e-04

# %%
# Summary of the final model
final_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_11     │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 1024)           │     1,311,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 4)              │         4,100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,015,537 (30.58 MB)
#  Trainable params: 1,320,452 (5.04 MB)
#  Non-trainable params: 4,054,179 (15.47 MB)
#  Optimizer params: 2,640,906 (10.07 MB)

# %%
# Extract values from the training history
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
auc = history.history['auc']
precision = history.history['precision']
recall = history.history['recall']
val_loss = history.history['val_loss']

# %%
# Calculate F1 Score for each epoch
f1_score = [2 * (p * r) / (p + r) if (p + r) > 0 else 0 for p, r in zip(precision, recall)]

# Plot Accuracy
plt.figure(figsize=(10, 6))
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot AUC
plt.figure(figsize=(10, 6))
plt.plot(auc, label='Training AUC')
plt.title('Training AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
# Plot Precision
plt.figure(figsize=(10, 6))
plt.plot(precision, label='Precision')
plt.title('Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %%
# Plot Recall
plt.figure(figsize=(10, 6))
plt.plot(recall, label='Recall')
plt.title('Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()
plt.show()

# %%
# Plot F1 Score
plt.figure(figsize=(10, 6))
plt.plot(f1_score, label='F1 Score')
plt.title('F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# %%
#Displaying Model Predictions and Actual Labels on Validation Data
# Define the class names (adjust based on your validation dataset)
class_names = validation_dataset.class_names

# Get predictions and true labels for the validation dataset
y_pred_probs = final_model.predict(validation_dataset)
y_pred = np.argmax(y_pred_probs, axis=-1)
y_true = np.concatenate([y for x, y in validation_dataset], axis=0)
y_true = np.argmax(y_true, axis=1)  # Convert to class indices if one-hot encoded

# Extract images from validation dataset
val_images = np.concatenate([x for x, y in validation_dataset], axis=0)

# Display a random sample of predictions alongside actual labels
plt.figure(figsize=(12, 12))
for i in range(9):  # Display 9 sample predictions
    idx = np.random.choice(range(len(val_images)))  # Randomly select an index
    image = val_images[idx]
    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]
    confidence = np.max(y_pred_probs[idx])

    plt.subplot(3, 3, i + 1)
    plt.imshow(image.astype("uint8"))
    plt.title(f"True: {true_label}\nPred: {pred_label} ({confidence:.2f})")
    plt.axis("off")
plt.suptitle("Model Predictions vs. Actual Labels on Validation Data")
plt.show()
# Out:
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 87s 1s/step
