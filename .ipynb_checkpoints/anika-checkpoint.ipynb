# %%
# !pip install optuna

# %%
import optuna
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# Load and preprocess the dataset
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'archive/split_leaves/train',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'archive/split_leaves/validation',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# Load EfficientNetB0 without top layers
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze initial layers

# Define the objective function for Optuna
def objective(trial):
    # Suggest values for dropout rate and learning rate
    dropout_rate = trial.suggest_float("dropout_rate", 0.3, 0.7)
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-3)

    # Build the model
    inputs = tf.keras.Input(shape=(224, 224, 3))
    x = data_augmentation(inputs)
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(4, activation='softmax')(x)  # Assuming 4 classes
    model = models.Model(inputs, outputs)

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Callbacks for early stopping and learning rate reduction
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, verbose=1)

    # Train the model with a small number of epochs for quick evaluation
    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=5,  # Reduced epochs to speed up optimization
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Return the best validation loss as the objective value
    val_loss = min(history.history['val_loss'])
    return val_loss

# Run the Optuna study
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)  # Run 10 trials for optimization

# Get the best parameters
best_params = study.best_params
print("Best parameters found by Optuna:", best_params)

# Final model with optimized parameters
best_dropout_rate = best_params['dropout_rate']
best_learning_rate = best_params['learning_rate']

# Build and compile the final model
final_model = models.Sequential([
    tf.keras.Input(shape=(224, 224, 3)),
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dropout(best_dropout_rate),
    layers.Dense(1024, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(best_dropout_rate),
    layers.Dense(4, activation='softmax')
])

# Compile with optimized learning rate
final_model.compile(optimizer=Adam(learning_rate=best_learning_rate),
                    loss='categorical_crossentropy',
                    metrics=['accuracy'])

# Callbacks for final training
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1)

# Train the final model
history = final_model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=15,  # Full training
    callbacks=[early_stopping, reduce_lr]
)

# Summary of the final model
final_model.summary()
# Out:
# Found 2531 files belonging to 4 classes.
# Found 633 files belonging to 4 classes.
# [I 2024-10-27 02:57:09,329] A new study created in memory with name: no-name-6003a377-8513-4280-95fd-595a3caffdf2
# Epoch 1/5
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_18464\122013686.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-3)
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 206s 2s/step - accuracy: 0.3433 - loss: 2.1899 - val_accuracy: 0.7314 - val_loss: 0.8007 - learning_rate: 4.4037e-05
# Epoch 2/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 156s 2s/step - accuracy: 0.6004 - loss: 1.2536 - val_accuracy: 0.7836 - val_loss: 0.5526 - learning_rate: 4.4037e-05
# Epoch 3/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.6979 - loss: 0.9230 - val_accuracy: 0.8420 - val_loss: 0.3988 - learning_rate: 4.4037e-05
# Epoch 4/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 162s 2s/step - accuracy: 0.7479 - loss: 0.8138 - val_accuracy: 0.8942 - val_loss: 0.2917 - learning_rate: 4.4037e-05
# Epoch 5/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.7793 - loss: 0.6613 - val_accuracy: 0.9179 - val_loss: 0.2247 - learning_rate: 4.4037e-05
# [I 2024-10-27 03:11:18,706] Trial 0 finished with value: 0.2247464805841446 and parameters: {'dropout_rate': 0.6142460942726169, 'learning_rate': 4.403727039884616e-05}. Best is trial 0 with value: 0.2247464805841446.
# Epoch 1/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 216s 2s/step - accuracy: 0.5902 - loss: 1.1394 - val_accuracy: 0.8863 - val_loss: 0.5426 - learning_rate: 1.1390e-04
# Epoch 2/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 161s 2s/step - accuracy: 0.8853 - loss: 0.3281 - val_accuracy: 0.9384 - val_loss: 0.2912 - learning_rate: 1.1390e-04
# Epoch 3/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 155s 2s/step - accuracy: 0.9205 - loss: 0.2119 - val_accuracy: 0.9668 - val_loss: 0.1606 - learning_rate: 1.1390e-04
# Epoch 4/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.9462 - loss: 0.1716 - val_accuracy: 0.9763 - val_loss: 0.0991 - learning_rate: 1.1390e-04
# Epoch 5/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.9545 - loss: 0.1362 - val_accuracy: 0.9779 - val_loss: 0.0760 - learning_rate: 1.1390e-04
# [I 2024-10-27 03:25:22,732] Trial 1 finished with value: 0.07598891109228134 and parameters: {'dropout_rate': 0.37253827479459367, 'learning_rate': 0.00011389840922220709}. Best is trial 1 with value: 0.07598891109228134.
# Epoch 1/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 216s 2s/step - accuracy: 0.2881 - loss: 2.5641 - val_accuracy: 0.7235 - val_loss: 1.0249 - learning_rate: 2.7978e-05
# Epoch 2/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.4456 - loss: 1.8358 - val_accuracy: 0.7773 - val_loss: 0.7281 - learning_rate: 2.7978e-05
# Epoch 3/5
# 80/80 ━━━━━━━━━━━━━━━━━━━━
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9469 - loss: 0.1492 - val_accuracy: 0.9479 - val_loss: 0.1307 - learning_rate: 6.9643e-04
# Epoch 4/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9664 - loss: 0.1063 - val_accuracy: 0.9700 - val_loss: 0.0699 - learning_rate: 6.9643e-04
# Epoch 5/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9676 - loss: 0.1086 - val_accuracy: 0.9779 - val_loss: 0.0654 - learning_rate: 6.9643e-04
# Epoch 6/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9695 - loss: 0.0872 - val_accuracy: 0.9858 - val_loss: 0.0414 - learning_rate: 6.9643e-04
# Epoch 7/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.9626 - loss: 0.1188 - val_accuracy: 0.9905 - val_loss: 0.0291 - learning_rate: 6.9643e-04
# Epoch 8/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9717 - loss: 0.0777 - val_accuracy: 0.9842 - val_loss: 0.0435 - learning_rate: 6.9643e-04
# Epoch 9/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9608 - loss: 0.1217 - val_accuracy: 0.9874 - val_loss: 0.0304 - learning_rate: 6.9643e-04
# Epoch 10/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.9723 - loss: 0.1020 - val_accuracy: 0.9905 - val_loss: 0.0255 - learning_rate: 6.9643e-04
# Epoch 11/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.9773 - loss: 0.0794 - val_accuracy: 0.9858 - val_loss: 0.0323 - learning_rate: 6.9643e-04
# Epoch 12/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9726 - loss: 0.0847 - val_accuracy: 0.9905 - val_loss: 0.0235 - learning_rate: 6.9643e-04
# Epoch 13/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9708 - loss: 0.0875 - val_accuracy: 0.9826 - val_loss: 0.0392 - learning_rate: 6.9643e-04
# Epoch 14/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9777 - loss: 0.0762 - val_accuracy: 0.9779 - val_loss: 0.0405 - learning_rate: 6.9643e-04
# Epoch 15/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9794 - loss: 0.0606
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00013928512344136835.
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9794 - loss: 0.0607 - val_accuracy: 0.9858 - val_loss: 0.0474 - learning_rate: 6.9643e-04
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential_2 (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_21     │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 1280)           │         5,120 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_42 (Dropout)            │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 1024)           │     1,311,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 1024)           │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_43 (Dropout)            │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 4)              │         4,100 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,015,537 (30.58 MB)
#  Trainable params: 1,320,452 (5.04 MB)
#  Non-trainable params: 4,054,179 (15.47 MB)
#  Optimizer params: 2,640,906 (10.07 MB)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(labels[i].numpy())
        plt.axis("off")
