# %%
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Rescaling, GlobalAveragePooling2D, Multiply
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau


def channel_attention(input_feature, ratio=8):
    channel = input_feature.shape[-1]

    shared_layer_one = Dense(channel // ratio, activation='relu', kernel_initializer='he_normal', use_bias=True)
    shared_layer_two = Dense(channel, kernel_initializer='he_normal', use_bias=True)

    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)

    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)

    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Activation('sigmoid')(cbam_feature)

    return Multiply()([input_feature, cbam_feature])


train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'archive/split_leaves/train',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)
validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'archive/split_leaves/validation',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)


rescale = Rescaling(1./255)

inputs = layers.Input(shape=(224, 224, 3))
x = rescale(inputs)


x = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = channel_attention(x)  
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.25)(x)


x = Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = channel_attention(x)  
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.25)(x)


x = Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = channel_attention(x)  
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.5)(x)


x = Conv2D(filters=512, kernel_size=(3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = channel_attention(x)  
x = MaxPooling2D(pool_size=(2, 2))(x)
x = Dropout(0.5)(x)


x = Flatten()(x)

x = Dense(units=512, activation='relu')(x)
x = Dropout(0.5)(x)

x = Dense(units=256, activation='relu')(x)
x = Dropout(0.5)(x)

outputs = Dense(units=4, activation='softmax')(x)


model = models.Model(inputs=inputs, outputs=outputs)


model.compile(optimizer=Adam(learning_rate=0.0001),  
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.summary()

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

history = model.fit(train_dataset,
                    epochs=20,
                    validation_data=validation_dataset,
                    callbacks=[early_stopping, lr_scheduler])
# Out:
# Found 2531 files belonging to 4 classes.
# Found 633 files belonging to 4 classes.
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_1         │ (None, 224, 224,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 222, 222,  │      1,792 │ rescaling_1[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 222, 222,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 64)        │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 64)  │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 64)  │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1, 1, 8)   │        520 │ reshape_2[0][0],  │
# │                     │                   │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1, 1, 64)  │        576 │ dense_2[0][0],    │
# │                     │                   │            │ dense_2[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 1, 1, 64)  │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_3[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1, 1, 64)  │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 222, 222,  │          0 │ batch_normalizat… │
# │ (Multiply)          │ 64)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 111, 111,  │          0 │ multiply_1[0][0]  │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 111, 111,  │          0 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 109, 109,  │     73,856 │ dropout[0][0]     │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 109, 109,  │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 128) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_5 (Reshape) │ (None, 1, 1, 128) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 1, 1, 16)  │      2,064 │ reshape_4[0][0],  │
# │                     │                   │            │ reshape_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1, 1, 128) │      2,176 │ dense_4[0][0],    │
# │                     │                   │            │ dense_4[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 1, 1, 128) │          0 │ dense_5[0][0],    │
# │                     │                   │            │ dense_5[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 1, 1, 128) │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 109, 109,  │          0 │ batch_normalizat… │
# │ (Multiply)          │ 128)              │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 54, 54,    │          0 │ multiply_2[0][0]  │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 54, 54,    │          0 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 52, 52,    │    295,168 │ dropout_1[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 52, 52,    │      1,024 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 256)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_6 (Reshape) │ (None, 1, 1, 256) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_7 (Reshape) │ (None, 1, 1, 256) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 1, 1, 32)  │      8,224 │ reshape_6[0][0],  │
# │                     │                   │            │ reshape_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 1, 1, 256) │      8,448 │ dense_6[0][0],    │
# │                     │                   │            │ dense_6[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 1, 1, 256) │          0 │ dense_7[0][0],    │
# │                     │                   │            │ dense_7[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 1, 1, 256) │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 52, 52,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 256)              │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 26, 26,    │          0 │ multiply_3[0][0]  │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 26, 26,    │          0 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 24, 24,    │  1,180,160 │ dropout_2[0][0]   │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 24,    │      2,048 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_8 (Reshape) │ (None, 1, 1, 512) │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_9 (Reshape) │ (None, 1, 1, 512) │          0 │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 1, 1, 64)  │     32,832 │ reshape_8[0][0],  │
# │                     │                   │            │ reshape_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 1, 1, 512) │     33,280 │ dense_8[0][0],    │
# │                     │                   │            │ dense_8[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 1, 1, 512) │          0 │ dense_9[0][0],    │
# │                     │                   │            │ dense_9[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 1, 1, 512) │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 24, 24,    │          0 │ batch_normalizat… │
# │ (Multiply)          │ 512)              │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 12, 12,    │          0 │ multiply_4[0][0]  │
# │ (MaxPooling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 12, 12,    │          0 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 73728)     │          0 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_10 (Dense)    │ (None, 512)       │ 37,749,248 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 512)       │          0 │ dense_10[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_11 (Dense)    │ (None, 256)       │    131,328 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 256)       │          0 │ dense_11[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_12 (Dense)    │ (None, 4)         │      1,028 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 39,524,540 (150.77 MB)
#  Trainable params: 39,522,620 (150.77 MB)
#  Non-trainable params: 1,920 (7.50 KB)
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1118s 14s/step - accuracy: 0.5382 - loss: 2.2615 - val_accuracy: 0.5182 - val_loss: 1.2276 - learning_rate: 1.0000e-04
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 947s 12s/step - accuracy: 0.8093 - loss: 0.6183 - val_accuracy: 0.5182 - val_loss: 1.1756 - learning_rate: 1.0000e-04
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 321s 4s/step - accuracy: 0.8553 - loss: 0.4667 - val_accuracy: 0.6272 - val_loss: 1.5013 - learning_rate: 1.0000e-04
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 321s 4s/step - accuracy: 0.9024 - loss: 0.3136 - val_accuracy: 0.1090 - val_loss: 1.9443 - learning_rate: 1.0000e-04
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 321s 4s/step - accuracy: 0.9280 - loss: 0.2380 - val_accuracy: 0.2212 - val_loss: 3.0735 - learning_rate: 1.0000e-04
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 322s 4s/step - accuracy: 0.9390 - loss: 0.1870 - val_accuracy: 0.3807 - val_loss: 3.0134 - learning_rate: 5.0000e-05
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 328s 4s/step - accuracy: 0.9413 - loss: 0.1749 - val_accuracy: 0.5324 - val_loss: 1.8284 - learning_rate: 5.0000e-05

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Rescaling, GlobalAveragePooling2D, Multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Channel attention mechanism
def channel_attention(input_feature, ratio=8):
    channel = input_feature.shape[-1]
    shared_layer_one = Dense(channel // ratio, activation='relu', kernel_initializer='he_normal', use_bias=True)
    shared_layer_two = Dense(channel, kernel_initializer='he_normal', use_bias=True)
    
    avg_pool = GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    
    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)
    
    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Activation('sigmoid')(cbam_feature)
    return Multiply()([input_feature, cbam_feature])

# Modified objective function with early stopping and reduced patience for hyperparameter search
# Modified objective function with epoch display (verbose=1)
def objective_function(params):
    lr, dropout_rate = params
    model = create_model(lr, dropout_rate)
    
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2, min_lr=1e-6)
    
    # Set verbose=1 to display training progress during Firefly search
    history = model.fit(train_dataset, epochs=10, validation_data=validation_dataset,
                        callbacks=[early_stopping, lr_scheduler], verbose=1)
    
    val_loss = min(history.history['val_loss'])
    return val_loss


# Firefly algorithm for hyperparameter optimization
def firefly_algorithm(n, max_gen, alpha=0.5, beta_min=0.2, gamma=1.0):
    fireflies = np.random.uniform(low=[1e-5, 0.0], high=[1e-3, 0.5], size=(n, 2))
    fitness = np.zeros(n)
    
    for gen in range(max_gen):
        for i in range(n):
            fitness[i] = objective_function(fireflies[i])
        
        indices = np.argsort(fitness)
        fireflies = fireflies[indices]
        
        for i in range(n):
            for j in range(n):
                if fitness[i] > fitness[j]:
                    r = np.linalg.norm(fireflies[i] - fireflies[j])
                    beta = beta_min + (1 - beta_min) * np.exp(-gamma * r ** 2)
                    fireflies[i] += beta * (fireflies[j] - fireflies[i]) + alpha * (np.random.rand(2) - 0.5)
                    fireflies[i] = np.clip(fireflies[i], [1e-5, 0.0], [1e-3, 0.5])
                    
    best_firefly = fireflies[0]
    return best_firefly

# Updated model creation function with improvements
def create_model(lr, dropout_rate):
    inputs = layers.Input(shape=(224, 224, 3))
    x = Rescaling(1./255)(inputs)
    
    # First Convolutional Block
    x = Conv2D(filters=64, kernel_size=(3, 3), activation='relu')(x)
    x = BatchNormalization()(x)
    x = channel_attention(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(dropout_rate)(x)
    
    # Second Convolutional Block
    x = Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(x)
    x = BatchNormalization()(x)
    x = channel_attention(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(dropout_rate)(x)
    
    # Third Convolutional Block
    x = Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(x)
    x = BatchNormalization()(x)
    x = channel_attention(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(dropout_rate)(x)
    
    # Fourth Convolutional Block
    x = Conv2D(filters=512, kernel_size=(3, 3), activation='relu')(x)
    x = BatchNormalization()(x)
    x = channel_attention(x)
    x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Dropout(dropout_rate)(x)
    
    # Fully connected layers
    x = Flatten()(x)
    x = Dense(units=512, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(units=256, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    
    # Output layer (4 classes for classification)
    outputs = Dense(units=4, activation='softmax')(x)
    
    model = models.Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer=Adam(learning_rate=lr), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Assuming data handling for train and validation datasets
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'archive/split_leaves/train',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    'archive/split_leaves/validation',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

# Firefly Algorithm to find the best hyperparameters (learning rate and dropout rate)
best_params = firefly_algorithm(n=10, max_gen=5)
best_lr, best_dropout_rate = best_params

# Create the final model with the best parameters
model = create_model(best_lr, best_dropout_rate)

# Callbacks for the main model training
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)

# Train the final model
history = model.fit(train_dataset, epochs=20, validation_data=validation_dataset, 
                    callbacks=[early_stopping, lr_scheduler])

# Model summary
model.summary()
# Out:
# Found 2531 files belonging to 4 classes.
# Found 633 files belonging to 4 classes.
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1126s 14s/step - accuracy: 0.7369 - loss: 3.1524 - val_accuracy: 0.0869 - val_loss: 19.1750 - learning_rate: 6.1080e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1087s 14s/step - accuracy: 0.9255 - loss: 0.4123 - val_accuracy: 0.0869 - val_loss: 27.1983 - learning_rate: 6.1080e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1097s 14s/step - accuracy: 0.9470 - loss: 0.2238 - val_accuracy: 0.0869 - val_loss: 33.2605 - learning_rate: 6.1080e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1093s 14s/step - accuracy: 0.9576 - loss: 0.1996 - val_accuracy: 0.4692 - val_loss: 14.5156 - learning_rate: 3.0540e-04
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1085s 14s/step - accuracy: 0.9899 - loss: 0.0469 - val_accuracy: 0.5893 - val_loss: 13.3913 - learning_rate: 3.0540e-04
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1084s 14s/step - accuracy: 0.9831 - loss: 0.0545 - val_accuracy: 0.6288 - val_loss: 5.6602 - learning_rate: 3.0540e-04
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1083s 14s/step - accuracy: 0.9955 - loss: 0.0139 - val_accuracy: 0.7014 - val_loss: 2.5897 - learning_rate: 3.0540e-04
# Epoch 8/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1084s 14s/step - accuracy: 0.9983 - loss: 0.0106 - val_accuracy: 0.7709 - val_loss: 1.4188 - learning_rate: 3.0540e-04
# Epoch 9/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1080s 14s/step - accuracy: 0.9757 - loss: 0.1013 - val_accuracy: 0.8926 - val_loss: 0.5212 - learning_rate: 3.0540e-04
# Epoch 10/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1082s 14s/step - accuracy: 0.9789 - loss: 0.0581 - val_accuracy: 0.9542 - val_loss: 0.2093 - learning_rate: 3.0540e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1141s 14s/step - accuracy: 0.7409 - loss: 1.3638 - val_accuracy: 0.1991 - val_loss: 3.5364 - learning_rate: 2.0712e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1097s 14s/step - accuracy: 0.9437 - loss: 0.1900 - val_accuracy: 0.5182 - val_loss: 1.3283 - learning_rate: 2.0712e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1088s 14s/step - accuracy: 0.9507 - loss: 0.1854 - val_accuracy: 0.5182 - val_loss: 4.1641 - learning_rate: 2.0712e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1122s 14s/step - accuracy: 0.9653 - loss: 0.1233 - val_accuracy: 0.5182 - val_loss: 5.8986 - learning_rate: 2.0712e-04
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1090s 14s/step - accuracy: 0.9843 - loss: 0.0482 - val_accuracy: 0.5071 - val_loss: 5.1510 - learning_rate: 1.0356e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1165s 14s/step - accuracy: 0.5789 - loss: 4.1927 - val_accuracy: 0.0869 - val_loss: 13.2493 - learning_rate: 6.6417e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1130s 14s/step - accuracy: 0.8271 - loss: 1.0298 - val_accuracy: 0.0869 - val_loss: 6.2640 - learning_rate: 6.6417e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1105s 14s/step - accuracy: 0.8979 - loss: 0.4024 - val_accuracy: 0.0869 - val_loss: 9.1953 - learning_rate: 6.6417e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1090s 14s/step - accuracy: 0.9141 - loss: 0.3621 - val_accuracy: 0.2638 - val_loss: 7.4933 - learning_rate: 6.6417e-04
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1097s 14s/step - accuracy: 0.9531 - loss: 0.1850 - val_accuracy: 0.4092 - val_loss: 7.5615 - learning_rate: 3.3209e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1118s 14s/step - accuracy: 0.6731 - loss: 2.6380 - val_accuracy: 0.1991 - val_loss: 6.3260 - learning_rate: 4.5133e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1086s 14s/step - accuracy: 0.8519 - loss: 0.6205 - val_accuracy: 0.0995 - val_loss: 5.4395 - learning_rate: 4.5133e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1088s 14s/step - accuracy: 0.9338 - loss: 0.2721 - val_accuracy: 0.0869 - val_loss: 11.3273 - learning_rate: 4.5133e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1089s 14s/step - accuracy: 0.9208 - loss: 0.3004 - val_accuracy: 0.0869 - val_loss: 20.2694 - learning_rate: 4.5133e-04
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1092s 14s/step - accuracy: 0.9616 - loss: 0.1319 - val_accuracy: 0.0995 - val_loss: 10.9408 - learning_rate: 2.2567e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1113s 14s/step - accuracy: 0.6850 - loss: 1.4218 - val_accuracy: 0.1991 - val_loss: 9.9493 - learning_rate: 1.4533e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1084s 14s/step - accuracy: 0.9054 - loss: 0.3155 - val_accuracy: 0.1991 - val_loss: 6.4925 - learning_rate: 1.4533e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1085s 14s/step - accuracy: 0.9258 - loss: 0.2150 - val_accuracy: 0.0869 - val_loss: 4.6156 - learning_rate: 1.4533e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1081s 14s/step - accuracy: 0.9334 - loss: 0.2301 - val_accuracy: 0.0869 - val_loss: 4.6256 - learning_rate: 1.4533e-04
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1083s 14s/step - accuracy: 0.9653 - loss: 0.0982 - val_accuracy: 0.1374 - val_loss: 8.0093 - learning_rate: 1.4533e-04
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1082s 14s/step - accuracy: 0.9799 - loss: 0.0493 - val_accuracy: 0.5450 - val_loss: 7.0597 - learning_rate: 7.2667e-05
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1105s 13s/step - accuracy: 0.4965 - loss: 4.2816 - val_accuracy: 0.0869 - val_loss: 5.0742 - learning_rate: 2.9167e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1084s 14s/step - accuracy: 0.8173 - loss: 0.6856 - val_accuracy: 0.0869 - val_loss: 6.9003 - learning_rate: 2.9167e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1105s 14s/step - accuracy: 0.8623 - loss: 0.4651 - val_accuracy: 0.0869 - val_loss: 10.4129 - learning_rate: 2.9167e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8109s 102s/step - accuracy: 0.8952 - loss: 0.3389 - val_accuracy: 0.0869 - val_loss: 12.7098 - learning_rate: 1.4584e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1159s 14s/step - accuracy: 0.7014 - loss: 3.2516 - val_accuracy: 0.1991 - val_loss: 8.3941 - learning_rate: 6.5803e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1118s 14s/step - accuracy: 0.8719 - loss: 0.7372 - val_accuracy: 0.0869 - val_loss: 12.8579 - learning_rate: 6.5803e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1117s 14s/step - accuracy: 0.9118 - loss: 0.4536 - val_accuracy: 0.0869 - val_loss: 14.3172 - learning_rate: 6.5803e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3584s 45s/step - accuracy: 0.9587 - loss: 0.1631 - val_accuracy: 0.0995 - val_loss: 11.1210 - learning_rate: 3.2902e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1137s 14s/step - accuracy: 0.6115 - loss: 3.8389 - val_accuracy: 0.1406 - val_loss: 7.9805 - learning_rate: 5.4226e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1116s 14s/step - accuracy: 0.8523 - loss: 0.8095 - val_accuracy: 0.0869 - val_loss: 6.8701 - learning_rate: 5.4226e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 26712s 338s/step - accuracy: 0.8916 - loss: 0.5084 - val_accuracy: 0.0869 - val_loss: 9.2116 - learning_rate: 5.4226e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1084s 14s/step - accuracy: 0.9226 - loss: 0.3433 - val_accuracy: 0.0995 - val_loss: 12.5559 - learning_rate: 5.4226e-04
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1085s 14s/step - accuracy: 0.9422 - loss: 0.2195 - val_accuracy: 0.1374 - val_loss: 18.2138 - learning_rate: 2.7113e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1125s 14s/step - accuracy: 0.4837 - loss: 3.0264 - val_accuracy: 0.1991 - val_loss: 4.8837 - learning_rate: 1.4295e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1088s 14s/step - accuracy: 0.7185 - loss: 0.8414 - val_accuracy: 0.1991 - val_loss: 6.7699 - learning_rate: 1.4295e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1085s 14s/step - accuracy: 0.8088 - loss: 0.5800 - val_accuracy: 0.1991 - val_loss: 3.9287 - learning_rate: 1.4295e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1087s 14s/step - accuracy: 0.8240 - loss: 0.4935 - val_accuracy: 0.2385 - val_loss: 3.0103 - learning_rate: 1.4295e-04
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1104s 14s/step - accuracy: 0.8580 - loss: 0.4349 - val_accuracy: 0.5276 - val_loss: 3.9554 - learning_rate: 1.4295e-04
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1212s 15s/step - accuracy: 0.8981 - loss: 0.2928 - val_accuracy: 0.5182 - val_loss: 4.7812 - learning_rate: 1.4295e-04
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1105s 14s/step - accuracy: 0.9234 - loss: 0.2420 - val_accuracy: 0.5482 - val_loss: 3.2880 - learning_rate: 7.1474e-05
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1139s 14s/step - accuracy: 0.6328 - loss: 1.2472 - val_accuracy: 0.5182 - val_loss: 1.2949 - learning_rate: 8.2782e-05
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1090s 14s/step - accuracy: 0.8713 - loss: 0.3944 - val_accuracy: 0.1991 - val_loss: 1.4779 - learning_rate: 8.2782e-05
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1090s 14s/step - accuracy: 0.9203 - loss: 0.2537 - val_accuracy: 0.0869 - val_loss: 3.0058 - learning_rate: 8.2782e-05
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1091s 14s/step - accuracy: 0.9317 - loss: 0.1998 - val_accuracy: 0.0869 - val_loss: 4.3742 - learning_rate: 4.1391e-05
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1118s 14s/step - accuracy: 0.7624 - loss: 1.8109 - val_accuracy: 0.5182 - val_loss: 7.0811 - learning_rate: 6.1080e-04
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1088s 14s/step - accuracy: 0.9053 - loss: 0.3858 - val_accuracy: 0.2496 - val_loss: 11.9752 - learning_rate: 6.1080e-04
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1088s 14s/step - accuracy: 0.9543 - loss: 0.1473 - val_accuracy: 0.0869 - val_loss: 21.7539 - learning_rate: 6.1080e-04
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1092s 14s/step - accuracy: 0.9691 - loss: 0.0863 - val_accuracy: 0.1975 - val_loss: 14.4178 - learning_rate: 3.0540e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1132s 14s/step - accuracy: 0.7220 - loss: 0.6844 - val_accuracy: 0.0869 - val_loss: 1.5416 - learning_rate: 1.0000e-05
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1074s 13s/step - accuracy: 0.9784 - loss: 0.0850 - val_accuracy: 0.0869 - val_loss: 1.7330 - learning_rate: 1.0000e-05
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1065s 13s/step - accuracy: 0.9939 - loss: 0.0367 - val_accuracy: 0.0869 - val_loss: 1.8187 - learning_rate: 1.0000e-05
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1066s 13s/step - accuracy: 0.9979 - loss: 0.0173 - val_accuracy: 0.0869 - val_loss: 1.8233 - learning_rate: 5.0000e-06
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1135s 14s/step - accuracy: 0.6401 - loss: 0.9480 - val_accuracy: 0.0869 - val_loss: 1.5325 - learning_rate: 1.0000e-05
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1114s 14s/step - accuracy: 0.8769 - loss: 0.3395 - val_accuracy: 0.0869 - val_loss: 1.7298 - learning_rate: 1.0000e-05
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1111s 14s/step - accuracy: 0.9142 - loss: 0.2528 - val_accuracy: 0.0869 - val_loss: 1.7536 - learning_rate: 1.0000e-05
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1111s 14s/step - accuracy: 0.9346 - loss: 0.1883 - val_accuracy: 0.0916 - val_loss: 1.7080 - learning_rate: 5.0000e-06
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1143s 14s/step - accuracy: 0.7162 - loss: 4.8555 - val_accuracy: 0.0869 - val_loss: 12.9277 - learning_rate: 0.0010
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1114s 14s/step - accuracy: 0.8875 - loss: 0.7672 - val_accuracy: 0.0869 - val_loss: 29.7639 - learning_rate: 0.0010
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1114s 14s/step - accuracy: 0.9085 - loss: 0.5821 - val_accuracy: 0.4376 - val_loss: 9.1117 - learning_rate: 0.0010
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1111s 14s/step - accuracy: 0.9470 - loss: 0.1830 - val_accuracy: 0.3965 - val_loss: 9.9529 - learning_rate: 0.0010
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1112s 14s/step - accuracy: 0.9612 - loss: 0.1444 - val_accuracy: 0.1137 - val_loss: 18.4235 - learning_rate: 0.0010
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1112s 14s/step - accuracy: 0.9751 - loss: 0.0889 - val_accuracy: 0.3823 - val_loss: 9.5108 - learning_rate: 5.0000e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1142s 14s/step - accuracy: 0.6606 - loss: 4.9663 - val_accuracy: 0.3318 - val_loss: 6.6652 - learning_rate: 0.0010
# Epoch 2/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1113s 14s/step - accuracy: 0.8770 - loss: 0.6540 - val_accuracy: 0.3254 - val_loss: 4.7217 - learning_rate: 0.0010
# Epoch 3/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1113s 14s/step - accuracy: 0.9215 - loss: 0.3198 - val_accuracy: 0.1043 - val_loss: 15.5761 - learning_rate: 0.0010
# Epoch 4/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1114s 14s/step - accuracy: 0.9286 - loss: 0.2452 - val_accuracy: 0.1517 - val_loss: 11.6579 - learning_rate: 0.0010
# Epoch 5/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1122s 14s/step - accuracy: 0.9658 - loss: 0.1183 - val_accuracy: 0.5276 - val_loss: 4.6504 - learning_rate: 5.0000e-04
# Epoch 6/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1126s 14s/step - accuracy: 0.9807 - loss: 0.0751 - val_accuracy: 0.5340 - val_loss: 4.4908 - learning_rate: 5.0000e-04
# Epoch 7/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1115s 14s/step - accuracy: 0.9835 - loss: 0.0490 - val_accuracy: 0.5608 - val_loss: 3.9183 - learning_rate: 5.0000e-04
# Epoch 8/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1159s 14s/step - accuracy: 0.9841 - loss: 0.0505 - val_accuracy: 0.8120 - val_loss: 0.8329 - learning_rate: 5.0000e-04
# Epoch 9/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 8311s 105s/step - accuracy: 0.9866 - loss: 0.0408 - val_accuracy: 0.8957 - val_loss: 0.4271 - learning_rate: 5.0000e-04
# Epoch 10/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1106s 14s/step - accuracy: 0.9854 - loss: 0.0384 - val_accuracy: 0.9210 - val_loss: 0.3254 - learning_rate: 5.0000e-04
# Epoch 1/10
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 18954s 239s/step - accuracy: 0.6584 - loss: 0.8777 - val_accuracy: 0.0869 - val_loss: 1.6193 - learning_rate: 1.0000e-05
# Epoch 2/10
# 36/80 ━━━━━━━━━━━━━━━━━━━━ 9:42 13s/step - accuracy: 0.9169 - loss: 0.2769
