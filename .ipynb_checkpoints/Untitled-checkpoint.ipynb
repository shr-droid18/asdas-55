# %%
import optuna
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.metrics import AUC, Precision, Recall
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load and preprocess the dataset
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '111/train',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)

validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '111/validation',
    image_size=(224, 224),
    batch_size=32,
    label_mode='categorical'
)
# Out:
# Found 7771 files belonging to 4 classes.
# Found 1943 files belonging to 4 classes.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(labels[i].numpy())
        plt.axis("off")

# %%
# Data augmentation
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %%
# Load EfficientNetB0 without top layers
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze initial layers

# %%
# Define the objective function for Optuna
def objective(trial):
    # Suggest values for dropout rate and learning rate
    dropout_rate = trial.suggest_float("dropout_rate", 0.3, 0.7)
    learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-3)

    # Build the model
    inputs = tf.keras.Input(shape=(224, 224, 3))
    x = data_augmentation(inputs)
    x = base_model(x, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(1024, activation='relu')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(4, activation='softmax')(x)  # Assuming 4 classes
    model = models.Model(inputs, outputs)

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=learning_rate),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    # Callbacks for early stopping and learning rate reduction
    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, verbose=1)

    # Train the model with a small number of epochs for quick evaluation
    history = model.fit(
        train_dataset,
        validation_data=validation_dataset,
        epochs=5,  # Reduced epochs to speed up optimization
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Return the best validation loss as the objective value
    val_loss = min(history.history['val_loss'])
    return val_loss

# %%
# Run the Optuna study
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=10)  # Run 10 trials for optimization
# Out:
# [I 2024-11-29 11:16:42,878] A new study created in memory with name: no-name-a06bf61d-532a-4999-bebd-93a7e978f40c
# Epoch 1/5
# C:\Users\Shreyas\AppData\Local\Temp\ipykernel_12084\2865568676.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform("learning_rate", 1e-5, 1e-3)
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 530s 2s/step - accuracy: 0.5661 - loss: 1.4866 - val_accuracy: 0.9331 - val_loss: 0.2278 - learning_rate: 1.4236e-04
# Epoch 2/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 467s 2s/step - accuracy: 0.8515 - loss: 0.4612 - val_accuracy: 0.9547 - val_loss: 0.1208 - learning_rate: 1.4236e-04
# Epoch 3/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 466s 2s/step - accuracy: 0.8885 - loss: 0.3479 - val_accuracy: 0.9629 - val_loss: 0.0959 - learning_rate: 1.4236e-04
# Epoch 4/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.9032 - loss: 0.3042 - val_accuracy: 0.9676 - val_loss: 0.0896 - learning_rate: 1.4236e-04
# Epoch 5/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 457s 2s/step - accuracy: 0.9059 - loss: 0.2919 - val_accuracy: 0.9722 - val_loss: 0.0765 - learning_rate: 1.4236e-04
# [I 2024-11-29 11:56:22,775] Trial 0 finished with value: 0.0765288919210434 and parameters: {'dropout_rate': 0.6795017760498085, 'learning_rate': 0.00014235983203168552}. Best is trial 0 with value: 0.0765288919210434.
# Epoch 1/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 518s 2s/step - accuracy: 0.6593 - loss: 0.9945 - val_accuracy: 0.9475 - val_loss: 0.2059 - learning_rate: 9.3886e-05
# Epoch 2/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 459s 2s/step - accuracy: 0.9033 - loss: 0.2867 - val_accuracy: 0.9722 - val_loss: 0.0869 - learning_rate: 9.3886e-05
# Epoch 3/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 462s 2s/step - accuracy: 0.9278 - loss: 0.2090 - val_accuracy: 0.9738 - val_loss: 0.0718 - learning_rate: 9.3886e-05
# Epoch 4/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.9337 - loss: 0.1764 - val_accuracy: 0.9820 - val_loss: 0.0562 - learning_rate: 9.3886e-05
# Epoch 5/5
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 461s 2s/step - accuracy: 0.9436 - loss: 0.1592 - val_accuracy: 0.9825 - val_loss: 0.0573 - learning_rate: 9.3886e-05
# [I 2024-11-29 12:35:43,854] Trial 1 finished with value: 0.05618991702795029 and parameters: {'dropout_rate': 0.5054606024304237, 'learning_rate': 9.388550272196493e-05}. Best is trial 1 with value: 0.05618991702795029.
# Epoch 1/5
# 237/243 ━━━━━━━━━━━━━━━━━━━━ 9s 2s/step - accuracy: 0.4887 - loss: 1.3861

# %%
# Get the best parameters
best_params = study.best_params
print("Best parameters found by Optuna:", best_params)
# Out:
# Best parameters found by Optuna: {'dropout_rate': 0.3543963563531263, 'learning_rate': 0.00016731976569666094}

# %%
# Final model with optimized parameters
best_dropout_rate = best_params['dropout_rate']
best_learning_rate = best_params['learning_rate']

# %%
# Build and compile the final model
final_model = models.Sequential([
    tf.keras.Input(shape=(224, 224, 3)),
    data_augmentation,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.BatchNormalization(),
    layers.Dropout(best_dropout_rate),
    layers.Dense(1024, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(best_dropout_rate),
    layers.Dense(4, activation='softmax')
])

# %%
# Compile with optimized learning rate
final_model.compile(optimizer=Adam(learning_rate=best_learning_rate),
                    loss='categorical_crossentropy',
                    metrics=['accuracy', AUC(name='auc'), Precision(name='precision'), Recall(name='recall')])

# %%
# Callbacks for final training
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, verbose=1)

# %%
# Train the final model
history = final_model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=15,  # Full training
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 228s 2s/step - accuracy: 0.6869 - auc: 0.8692 - loss: 0.9172 - precision: 0.7274 - recall: 0.6542 - val_accuracy: 0.9352 - val_auc: 0.9931 - val_loss: 0.4500 - val_precision: 0.9731 - val_recall: 0.7994 - learning_rate: 1.6732e-04
# Epoch 2/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9216 - auc: 0.9886 - loss: 0.2425 - precision: 0.9286 - recall: 0.9121 - val_accuracy: 0.9621 - val_auc: 0.9983 - val_loss: 0.2353 - val_precision: 0.9801 - val_recall: 0.9321 - learning_rate: 1.6732e-04
# Epoch 3/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9455 - auc: 0.9920 - loss: 0.1714 - precision: 0.9531 - recall: 0.9402 - val_accuracy: 0.9637 - val_auc: 0.9986 - val_loss: 0.1323 - val_precision: 0.9758 - val_recall: 0.9542 - learning_rate: 1.6732e-04
# Epoch 4/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.9441 - auc: 0.9929 - loss: 0.1754 - precision: 0.9487 - recall: 0.9359 - val_accuracy: 0.9779 - val_auc: 0.9995 - val_loss: 0.0731 - val_precision: 0.9824 - val_recall: 0.9716 - learning_rate: 1.6732e-04
# Epoch 5/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9405 - auc: 0.9952 - loss: 0.1512 - precision: 0.9490 - recall: 0.9359 - val_accuracy: 0.9795 - val_auc: 0.9997 - val_loss: 0.0527 - val_precision: 0.9857 - val_recall: 0.9779 - learning_rate: 1.6732e-04
# Epoch 6/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9615 - auc: 0.9971 - loss: 0.1030 - precision: 0.9679 - recall: 0.9608 - val_accuracy: 0.9842 - val_auc: 0.9997 - val_loss: 0.0428 - val_precision: 0.9842 - val_recall: 0.9826 - learning_rate: 1.6732e-04
# Epoch 7/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9685 - auc: 0.9981 - loss: 0.0916 - precision: 0.9717 - recall: 0.9668 - val_accuracy: 0.9858 - val_auc: 0.9997 - val_loss: 0.0406 - val_precision: 0.9873 - val_recall: 0.9842 - learning_rate: 1.6732e-04
# Epoch 8/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9678 - auc: 0.9982 - loss: 0.0913 - precision: 0.9702 - recall: 0.9662 - val_accuracy: 0.9858 - val_auc: 0.9997 - val_loss: 0.0377 - val_precision: 0.9858 - val_recall: 0.9858 - learning_rate: 1.6732e-04
# Epoch 9/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9687 - auc: 0.9982 - loss: 0.0897 - precision: 0.9712 - recall: 0.9680 - val_accuracy: 0.9905 - val_auc: 0.9998 - val_loss: 0.0334 - val_precision: 0.9905 - val_recall: 0.9905 - learning_rate: 1.6732e-04
# Epoch 10/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9721 - auc: 0.9982 - loss: 0.0703 - precision: 0.9752 - recall: 0.9709 - val_accuracy: 0.9937 - val_auc: 0.9998 - val_loss: 0.0286 - val_precision: 0.9937 - val_recall: 0.9937 - learning_rate: 1.6732e-04
# Epoch 11/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9624 - auc: 0.9978 - loss: 0.1013 - precision: 0.9651 - recall: 0.9599 - val_accuracy: 0.9905 - val_auc: 0.9999 - val_loss: 0.0267 - val_precision: 0.9921 - val_recall: 0.9905 - learning_rate: 1.6732e-04
# Epoch 12/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9682 - auc: 0.9979 - loss: 0.0826 - precision: 0.9696 - recall: 0.9658 - val_accuracy: 0.9874 - val_auc: 0.9999 - val_loss: 0.0274 - val_precision: 0.9874 - val_recall: 0.9874 - learning_rate: 1.6732e-04
# Epoch 13/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9715 - auc: 0.9985 - loss: 0.0777 - precision: 0.9734 - recall: 0.9696 - val_accuracy: 0.9889 - val_auc: 0.9999 - val_loss: 0.0289 - val_precision: 0.9889 - val_recall: 0.9889 - learning_rate: 1.6732e-04
# Epoch 14/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9761 - auc: 0.9992 - loss: 0.0612 - precision: 0.9795 - recall: 0.9750
# Epoch 14: ReduceLROnPlateau reducing learning rate to 3.346395387779921e-05.
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.9760 - auc: 0.9991 - loss: 0.0613 - precision: 0.9794 - recall: 0.9749 - val_accuracy: 0.9874 - val_auc: 0.9997 - val_loss: 0.0352 - val_precision: 0.9874 - val_recall: 0.9874 - learning_rate: 1.6732e-04
# Epoch 15/15
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.9737 - auc: 0.9970 - loss: 0.0828 - precision: 0.9756 - recall: 0.9725 - val_accuracy: 0.9889 - val_auc: 0.9999 - val_loss: 0.0274 - val_precision: 0.9889 - val_recall: 0.9889 - learning_rate: 3.3464e-05

# %%
# Summary of the final model
final_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_10          │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_20               │ (None, 1280)                │           5,120 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_20 (Dropout)                 │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1024)                │       1,311,744 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_21               │ (None, 1024)                │           4,096 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_21 (Dropout)                 │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 4)                   │           4,100 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,015,537 (30.58 MB)
#  Trainable params: 1,320,452 (5.04 MB)
#  Non-trainable params: 4,054,179 (15.47 MB)
#  Optimizer params: 2,640,906 (10.07 MB)

# %%
# Extract values from the training history
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
auc = history.history['auc']
precision = history.history['precision']
recall = history.history['recall']
val_loss = history.history['val_loss']

# %%
# Calculate F1 Score for each epoch
f1_score = [2 * (p * r) / (p + r) if (p + r) > 0 else 0 for p, r in zip(precision, recall)]

# Plot Accuracy
plt.figure(figsize=(10, 6))
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Plot AUC
plt.figure(figsize=(10, 6))
plt.plot(auc, label='Training AUC')
plt.title('Training AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.show()

# %%
# Plot Precision
plt.figure(figsize=(10, 6))
plt.plot(precision, label='Precision')
plt.title('Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %%
# Plot Recall
plt.figure(figsize=(10, 6))
plt.plot(recall, label='Recall')
plt.title('Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()
plt.show()

# %%
# Plot F1 Score
plt.figure(figsize=(10, 6))
plt.plot(f1_score, label='F1 Score')
plt.title('F1 Score')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.legend()
plt.show()

# %%
#Displaying Model Predictions and Actual Labels on Validation Data
# Define the class names (adjust based on your validation dataset)
class_names = validation_dataset.class_names

# Get predictions and true labels for the validation dataset
y_pred_probs = final_model.predict(validation_dataset)
y_pred = np.argmax(y_pred_probs, axis=-1)
y_true = np.concatenate([y for x, y in validation_dataset], axis=0)
y_true = np.argmax(y_true, axis=1)  # Convert to class indices if one-hot encoded

# Extract images from validation dataset
val_images = np.concatenate([x for x, y in validation_dataset], axis=0)

# Display a random sample of predictions alongside actual labels
plt.figure(figsize=(12, 12))
for i in range(9):  # Display 9 sample predictions
    idx = np.random.choice(range(len(val_images)))  # Randomly select an index
    image = val_images[idx]
    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]
    confidence = np.max(y_pred_probs[idx])

    plt.subplot(3, 3, i + 1)
    plt.imshow(image.astype("uint8"))
    plt.title(f"True: {true_label}\nPred: {pred_label} ({confidence:.2f})")
    plt.axis("off")
plt.suptitle("Model Predictions vs. Actual Labels on Validation Data")
plt.show()
